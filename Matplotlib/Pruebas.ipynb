# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
fig = plt.figure(figsize=(12, 7))
m = Basemap(width=4000 * 1000, height=3000 * 1000, projection="lcc", lat_0=49, lon_0=7)
m.shadedrelief()
plt.show()

# %%
import pandas as pd

data = {
    "Apple": 147000,
    "Samsung": 267937,
    "Google": 135301,
    "Microsoft": 163000,
    "Huawei": 197000,
    "Dell": 158000,
    "Facebook": 58604,
    "Foxconn": 878429,
    "Sony": 109700,
}

employees = pd.Series(data, name="Tech Employees")
employees.index
# Out:
# Index(['Apple', 'Samsung', 'Google', 'Microsoft', 'Huawei', 'Dell', 'Facebook',
#        'Foxconn', 'Sony'],
#       dtype='object')
